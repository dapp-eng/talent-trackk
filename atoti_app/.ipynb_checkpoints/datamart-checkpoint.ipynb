# %% [markdown]
# # TalentTrack — Atoti DataMart
# **Kelompok:** Daffa Ahmad Pangreksa · Halilatunnisa · Naura Kanaya Putri M.
# **Kelas:** 2024-INT | Data Warehouse | UNESA
#
# Notebook ini membangun DataMart menggunakan **Atoti** dengan 3 cube OLAP:
# 1. `JobPostings` — analisis umum posting pekerjaan
# 2. `SkillDemand` — analisis permintaan skill per kategori/region/waktu
# 3. `SkillForecast` — hasil forecasting permintaan skill 8 minggu ke depan
#
# ---
# **Prasyarat:**
# ```bash
# pip install atoti[all] sqlalchemy psycopg2-binary python-dotenv pandas
# ```
# Pastikan file `.env` ada di folder `talenttrack/` berisi credentials Supabase.

# %%
import subprocess, sys
subprocess.run([sys.executable, "-m", "pip", "install", "atoti[jupyterlab]"], check=True)
# Out:
# CompletedProcess(args=['C:\\Users\\Halilatunnisa\\atoti_fix\\Scripts\\python.exe', '-m', 'pip', 'install', 'atoti[jupyterlab]'], returncode=0)

# %%
import subprocess, sys
subprocess.run([sys.executable, "-m", "pip", "install", "python-dotenv", "sqlalchemy", "psycopg2-binary"], check=True)
# Out:
# CompletedProcess(args=['C:\\Users\\Halilatunnisa\\atoti_fix\\Scripts\\python.exe', '-m', 'pip', 'install', 'python-dotenv', 'sqlalchemy', 'psycopg2-binary'], returncode=0)

# %%
import subprocess, sys
result = subprocess.run([sys.executable, "-m", "pip", "show", "atoti"], capture_output=True, text=True)
print(result.stdout)
# Out:
# Name: atoti
# Version: 0.9.13
# Summary: Explore metrics across hundreds of dimensions, analyze live data at its most granular level and perform what-if simulations at unparalleled speed
# Home-page:
# Author: ActiveViam
# Author-email: ActiveViam <atoti-dev@activeviam.com>
# License:
# Location: c:\users\halilatunnisa\atoti_fix\lib\site-packages
# Requires: atoti-client-parquet, jdk4py, atoti-server-parquet, atoti-client, atoti-server
# Required-by:

# %%
import os
from pathlib import Path
from dotenv import load_dotenv

root = Path(os.getcwd()).parent  
sys.path.insert(0, str(root))

# %%
load_dotenv(root / ".env", override=True)
print("PGHOST:", os.getenv("PGHOST"))
print("PGDATABASE:", os.getenv("PGDATABASE"))
# Out:
# PGHOST: aws-1-ap-south-1.pooler.supabase.com
# PGDATABASE: postgres

# %%
import pandas as pd
import numpy as np
import atoti as tt
from sqlalchemy import create_engine

DB_URL = (
    f"postgresql://{os.getenv('PGUSER')}:{os.getenv('PGPASSWORD')}"
    f"@{os.getenv('PGHOST')}:{os.getenv('PGPORT', 5432)}/{os.getenv('PGDATABASE')}"
)
engine = create_engine(DB_URL, pool_pre_ping=True)
print("DB engine created")
# Out:
# Welcome to Atoti 0.9.13!
#
# By using this community edition, you agree with the license available at https://docs.activeviam.com/products/atoti/python-sdk/latest/eula.html.
# Browse the official documentation at https://docs.activeviam.com/products/atoti/python-sdk.
# Join the community at https://www.atoti.io/register.
#
# Atoti collects telemetry data, which is used to help understand how to improve the product.
# If you don't wish to send usage data, you can request a trial license at https://www.atoti.io/evaluation-license-request.
#
# You can hide this message by setting the `ATOTI_HIDE_EULA_MESSAGE` environment variable to True.
# DB engine created

# %% [markdown]
# ## 1. Load Data dari PostgreSQL

# %%
fact_df = pd.read_sql("""
    SELECT
        f.job_id,
        f.time_id,
        f.location_id,
        f.company_id,
        f.position_id,
        f.platform_id,
        f.posting_count,
        f.job_age_days,
        CASE WHEN f.has_salary THEN 1 ELSE 0 END AS has_salary,
        CASE WHEN f.is_remote  THEN 1 ELSE 0 END AS is_remote,
        f.salary_min,
        f.salary_max,
        dt.date,
        dt.week,
        dt.month,
        dt.quarter,
        dt.year,
        dt.week_label,
        dl.city,
        dl.province_state,
        dl.country,
        dl.global_region,
        dc.company_name,
        dc.industry_sector,
        dc.company_size_category,
        dp.normalized_job_title,
        dp.job_level,
        dp.job_category,
        dpl.platform_name
    FROM fact_job_posting f
    JOIN dim_time     dt  ON f.time_id     = dt.time_id
    JOIN dim_location dl  ON f.location_id = dl.location_id
    JOIN dim_company  dc  ON f.company_id  = dc.company_id
    JOIN dim_position dp  ON f.position_id = dp.position_id
    JOIN dim_platform dpl ON f.platform_id = dpl.platform_id;
""", engine)

fact_df["date"] = pd.to_datetime(fact_df["date"])
print(f"fact_job_posting : {len(fact_df):,} rows")
fact_df.head(3)
# Out:
# fact_job_posting : 335 rows
#    job_id  time_id  location_id  company_id  position_id  platform_id  \
# 0       1      473            1           1            1            1
# 1       2      467            2           2            2            1
# 2       3      472            3           3            3            1
#
#    posting_count  job_age_days  has_salary  is_remote  ...  province_state  \
# 0              1           765           0          0  ...            None
# 1              1           771           1          0  ...            None
# 2              1           766           1          0  ...            None
#
#    country global_region           company_name  industry_sector  \
# 0       NJ         Other  Corcoran Sawyer Smith             None
# 1       CO         Other                Unknown             None
# 2       OH         Other  The National Exemplar             None
#
#    company_size_category               normalized_job_title job_level  \
# 0                   None              marketing coordinator   Manager
# 1                   None  mental health therapist/counselor   Unknown
# 2                   None        assitant restaurant manager   Manager
#
#   job_category platform_name
# 0        Other      LinkedIn
# 1        Other      LinkedIn
# 2   Management      LinkedIn
#
# [3 rows x 29 columns]

# %%
skill_df = pd.read_sql("""
    SELECT
        b.job_id,
        b.skill_id,
        b.extraction_confidence,
        ds.skill_name,
        ds.skill_type,
        ds.skill_domain
    FROM bridge_job_skill b
    JOIN dim_skill ds ON b.skill_id = ds.skill_id;
""", engine)

print(f"bridge_job_skill + dim_skill : {len(skill_df):,} rows")
skill_df.head(3)
# Out:
# bridge_job_skill + dim_skill : 180 rows
#    job_id  skill_id  extraction_confidence            skill_name skill_type  \
# 0       1         1                  0.871  adobe creative cloud  Knowledge
# 1       1         2                  0.674              indesign  Knowledge
# 2       1         3                  0.699           illustrator  Knowledge
#
#                 skill_domain
# 0  urchade/gliner_small-v2.1
# 1  urchade/gliner_small-v2.1
# 2  urchade/gliner_small-v2.1

# %%
forecast_df = pd.read_sql("""
    SELECT
        fsd.skill_id,
        fsd.forecast_week_label,
        fsd.forecast_year,
        fsd.forecast_week,
        ds.skill_name,
        fsd.job_category,
        fsd.global_region,
        fsd.predicted_count,
        fsd.lower_bound,
        fsd.upper_bound,
        fsd.model_name
    FROM forecast_skill_demand fsd
    JOIN dim_skill ds ON fsd.skill_id = ds.skill_id;
""", engine)

print(f"forecast_skill_demand : {len(forecast_df):,} rows")
forecast_df.head(3)
# Out:
# forecast_skill_demand : 1,360 rows
#    skill_id forecast_week_label  forecast_year  forecast_week  \
# 0         1            2024-W22           2024             22
# 1         1            2024-W23           2024             23
# 2         1            2024-W24           2024             24
#
#              skill_name job_category global_region  predicted_count  \
# 0  adobe creative cloud        Other         Other              1.0
# 1  adobe creative cloud        Other         Other              1.0
# 2  adobe creative cloud        Other         Other              1.0
#
#    lower_bound  upper_bound model_name
# 0          1.0          1.0       mean
# 1          1.0          1.0       mean
# 2          1.0          1.0       mean

# %%
skill_fact_df = skill_df.merge(fact_df, on="job_id", how="left")

skill_fact_df["salary_min"] = pd.to_numeric(skill_fact_df["salary_min"], errors="coerce")
skill_fact_df["salary_max"] = pd.to_numeric(skill_fact_df["salary_max"], errors="coerce")
skill_fact_df["salary_midpoint"] = (
    (skill_fact_df["salary_min"].fillna(0) + skill_fact_df["salary_max"].fillna(0)) / 2
).replace(0, np.nan)

skill_fact_df["skill_count"] = 1

print(f"skill_fact_df merged : {len(skill_fact_df):,} rows")
skill_fact_df.head(3)
# Out:
# skill_fact_df merged : 180 rows
#    job_id  skill_id  extraction_confidence            skill_name skill_type  \
# 0       1         1                  0.871  adobe creative cloud  Knowledge
# 1       1         2                  0.674              indesign  Knowledge
# 2       1         3                  0.699           illustrator  Knowledge
#
#                 skill_domain  time_id  location_id  company_id  position_id  \
# 0  urchade/gliner_small-v2.1      473            1           1            1
# 1  urchade/gliner_small-v2.1      473            1           1            1
# 2  urchade/gliner_small-v2.1      473            1           1            1
#
#    ...  global_region           company_name  industry_sector  \
# 0  ...          Other  Corcoran Sawyer Smith             None
# 1  ...          Other  Corcoran Sawyer Smith             None
# 2  ...          Other  Corcoran Sawyer Smith             None
#
#    company_size_category   normalized_job_title  job_level  job_category  \
# 0                   None  marketing coordinator    Manager         Other
# 1                   None  marketing coordinator    Manager         Other
# 2                   None  marketing coordinator    Manager         Other
#
#   platform_name  salary_midpoint  skill_count
# 0      LinkedIn              NaN            1
# 1      LinkedIn              NaN            1
# 2      LinkedIn              NaN            1
#
# [3 rows x 36 columns]

# %% [markdown]
# ## 2. Buat Sesi Atoti

# %%
# fact_df
fact_df["salary_min"]            = fact_df["salary_min"].fillna(0)
fact_df["salary_max"]            = fact_df["salary_max"].fillna(0)
fact_df["city"]                  = fact_df["city"].fillna("Unknown")
fact_df["province_state"]        = fact_df["province_state"].fillna("Unknown")
fact_df["industry_sector"]       = fact_df["industry_sector"].fillna("Unknown")
fact_df["company_size_category"] = fact_df["company_size_category"].fillna("Unknown")

# skill_fact_df
str_cols = [
    "skill_domain", "skill_type", "skill_name",
    "job_category", "job_level", "normalized_job_title",
    "global_region", "country", "week_label", "platform_name",
    "city", "province_state", "industry_sector", "company_size_category"
]
for col in str_cols:
    if col in skill_fact_df.columns:
        skill_fact_df[col] = skill_fact_df[col].fillna("Unknown")
for col in ["year", "quarter", "month", "week"]:
    if col in skill_fact_df.columns:
        skill_fact_df[col] = skill_fact_df[col].fillna(0).astype(int)
skill_fact_df["extraction_confidence"] = skill_fact_df["extraction_confidence"].fillna(0.0)
skill_fact_df["salary_midpoint"]       = skill_fact_df["salary_midpoint"].fillna(0.0)

# forecast_df
for col in ["skill_name", "job_category", "global_region",
            "forecast_week_label", "model_name"]:
    forecast_df[col] = forecast_df[col].fillna("Unknown")
forecast_df["forecast_year"]   = forecast_df["forecast_year"].fillna(0).astype(int)
forecast_df["forecast_week"]   = forecast_df["forecast_week"].fillna(0).astype(int)
forecast_df["predicted_count"] = forecast_df["predicted_count"].fillna(0.0)
forecast_df["lower_bound"]     = forecast_df["lower_bound"].fillna(0.0)
forecast_df["upper_bound"]     = forecast_df["upper_bound"].fillna(0.0)

print("Fillna done")
# Out:
# Fillna done

# %%
session = tt.Session.start(
    tt.SessionConfig(port=9090)
)
print("Atoti session started")
print("Dashboard URL: http://localhost:9090/ui")
# Out:
# Atoti session started
# Dashboard URL: http://localhost:9090/ui

# %% [markdown]
# ## 3. Cube 1: JobPostings
# Analisis umum: volume posting, remote rate, salary coverage, per platform/region/waktu.

# %%
job_store = session.read_pandas(
    fact_df,
    table_name="job_postings",
    keys=["job_id"],
    default_values={
        "time_id": 0, "location_id": 0, "company_id": 0,
        "position_id": 0, "platform_id": 0,
        "year": 0, "quarter": 0, "month": 0, "week": 0,
        "week_label": "Unknown", "city": "Unknown",
        "province_state": "Unknown", "global_region": "Unknown",
        "country": "Unknown", "industry_sector": "Unknown",
        "company_size_category": "Unknown", "company_name": "Unknown",
        "normalized_job_title": "Unknown", "job_level": "Unknown",
        "job_category": "Unknown", "platform_name": "Unknown",
        "salary_min": 0.0, "salary_max": 0.0,
        "posting_count": 0, "job_age_days": 0,
        "has_salary": 0, "is_remote": 0,
    }
)

job_cube = session.create_cube(job_store, name="JobPostings")
h = job_cube.hierarchies
m = job_cube.measures

h["Time"]     = [job_store["year"], job_store["quarter"],
                  job_store["month"], job_store["week_label"]]
h["Location"] = [job_store["global_region"], job_store["country"],
                  job_store["city"]]
h["Job"]      = [job_store["job_category"], job_store["job_level"],
                  job_store["normalized_job_title"]]
h["Company"]  = [job_store["industry_sector"],
                  job_store["company_size_category"], job_store["company_name"]]
h["Platform"] = [job_store["platform_name"]]

m["Total Postings"]       = tt.agg.sum(job_store["posting_count"])
m["Remote Postings"]      = tt.agg.sum(job_store["is_remote"])
m["Remote Rate"]          = m["Remote Postings"] / m["Total Postings"]
m["Avg Salary Min"]       = tt.agg.mean(job_store["salary_min"])
m["Avg Salary Max"]       = tt.agg.mean(job_store["salary_max"])
m["Avg Job Age Days"]     = tt.agg.mean(job_store["job_age_days"])
m["With Salary Count"]    = tt.agg.sum(job_store["has_salary"])
m["Salary Coverage Rate"] = m["With Salary Count"] / m["Total Postings"]

print("Cube 1 (JobPostings) created")
# Out:
# Cube 1 (JobPostings) created

# %% [markdown]
# ## 4. Cube 2: SkillDemand
# Analisis permintaan skill: skill apa paling banyak diminta, per kategori, region, waktu.

# %%
skill_store = session.read_pandas(
    skill_fact_df,
    table_name="skill_facts",
    keys=["job_id", "skill_name"],
    default_values={
        "skill_id": 0,
        "skill_domain": "Unknown", "skill_type": "Unknown", "skill_name": "Unknown",
        "job_category": "Unknown", "job_level": "Unknown",
        "normalized_job_title": "Unknown",
        "global_region": "Unknown", "country": "Unknown",
        "year": 0, "quarter": 0, "month": 0, "week_label": "Unknown",
        "platform_name": "Unknown",
        "extraction_confidence": 0.0,
        "salary_midpoint": 0.0,
        "skill_count": 0,
    }
)

skill_cube = session.create_cube(skill_store, name="SkillDemand")
sh = skill_cube.hierarchies
sm = skill_cube.measures

sh["Skill"]    = [skill_store["skill_domain"], skill_store["skill_type"],
                   skill_store["skill_name"]]
sh["Job"]      = [skill_store["job_category"], skill_store["job_level"],
                   skill_store["normalized_job_title"]]
sh["Location"] = [skill_store["global_region"], skill_store["country"]]
sh["Time"]     = [skill_store["year"], skill_store["quarter"],
                   skill_store["month"], skill_store["week_label"]]
sh["Platform"] = [skill_store["platform_name"]]

sm["Skill Postings"]      = tt.agg.sum(skill_store["skill_count"])
sm["Avg Confidence"]      = tt.agg.mean(skill_store["extraction_confidence"])
sm["Avg Salary Midpoint"] = tt.agg.mean(skill_store["salary_midpoint"])

print("Cube 2 (SkillDemand) created")
# Out:
# Cube 2 (SkillDemand) created

# %% [markdown]
# ## 5. Cube 3: SkillForecast
# Hasil forecasting Holt-Winters/Linear Trend: prediksi permintaan skill 8 minggu ke depan.

# %%
forecast_store = session.read_pandas(
    forecast_df,
    table_name="skill_forecasts",
    keys=["forecast_week_label", "skill_name", "job_category", "global_region"],
    default_values={
        "skill_id": 0,
        "skill_name": "Unknown",
        "job_category": "Unknown", "global_region": "Unknown",
        "forecast_year": 0, "forecast_week": 0,
        "forecast_week_label": "Unknown", "model_name": "Unknown",
        "predicted_count": 0.0, "lower_bound": 0.0, "upper_bound": 0.0,
    }
)

forecast_cube = session.create_cube(forecast_store, name="SkillForecast")
fh = forecast_cube.hierarchies
fm = forecast_cube.measures

fh["Skill"]         = [forecast_store["skill_name"]] 
fh["Job"]           = [forecast_store["job_category"]]
fh["Location"]      = [forecast_store["global_region"]]
fh["Forecast Time"] = [forecast_store["forecast_year"], forecast_store["forecast_week"],
                         forecast_store["forecast_week_label"]]
fh["Model"]         = [forecast_store["model_name"]]

fm["Predicted Postings"] = tt.agg.sum(forecast_store["predicted_count"])
fm["Forecast Lower"]     = tt.agg.sum(forecast_store["lower_bound"])
fm["Forecast Upper"]     = tt.agg.sum(forecast_store["upper_bound"])
fm["Forecast Range"]     = fm["Forecast Upper"] - fm["Forecast Lower"]

print("Cube 3 (SkillForecast) created")
# Out:
# Cube 3 (SkillForecast) created

# %%
dim_time_df     = pd.read_sql("SELECT * FROM dim_time",     engine)
dim_location_df = pd.read_sql("SELECT * FROM dim_location", engine)
dim_company_df  = pd.read_sql("SELECT * FROM dim_company",  engine)
dim_position_df = pd.read_sql("SELECT * FROM dim_position", engine)
dim_platform_df = pd.read_sql("SELECT * FROM dim_platform", engine)
dim_skill_df    = pd.read_sql("SELECT * FROM dim_skill",    engine)

# Fillna dimensi
for col in dim_time_df.select_dtypes(include="object").columns:
    dim_time_df[col] = dim_time_df[col].fillna("Unknown")
for df in [dim_location_df, dim_company_df, dim_position_df,
           dim_platform_df, dim_skill_df]:
    for col in df.select_dtypes(include="object").columns:
        df[col] = df[col].fillna("Unknown")
    for col in df.select_dtypes(include="number").columns:
        df[col] = df[col].fillna(0)

print("Dimensi loaded")
# Out:
# Dimensi loaded

# %%
# Load ke Atoti
dim_time_store     = session.read_pandas(dim_time_df,     table_name="dim_time",     keys=["time_id"])
dim_location_store = session.read_pandas(dim_location_df, table_name="dim_location", keys=["location_id"])
dim_company_store  = session.read_pandas(dim_company_df,  table_name="dim_company",  keys=["company_id"])
dim_position_store = session.read_pandas(dim_position_df, table_name="dim_position", keys=["position_id"])
dim_platform_store = session.read_pandas(dim_platform_df, table_name="dim_platform", keys=["platform_id"])
dim_skill_store    = session.read_pandas(dim_skill_df,    table_name="dim_skill",    keys=["skill_id"])

print("Dimensi loaded")

# fact_job_posting → semua dimensi
job_store.join(dim_time_store,     job_store["time_id"]     == dim_time_store["time_id"])
job_store.join(dim_location_store, job_store["location_id"] == dim_location_store["location_id"])
job_store.join(dim_company_store,  job_store["company_id"]  == dim_company_store["company_id"])
job_store.join(dim_position_store, job_store["position_id"] == dim_position_store["position_id"])
job_store.join(dim_platform_store, job_store["platform_id"] == dim_platform_store["platform_id"])

# bridge_job_skill → dim_skill
skill_store.join(dim_skill_store, skill_store["skill_id"] == dim_skill_store["skill_id"])
# Out:
# Dimensi loaded

# %%
session.tables.schema
# Out:
# erDiagram
#   "job_postings" {
#     non-null long PK "job_id"
#     non-null long "time_id"
#     non-null long "location_id"
#     non-null long "company_id"
#     non-null long "position_id"
#     non-null long "platform_id"
#     non-null long "posting_count"
#     non-null long "job_age_days"
#     non-null long "has_salary"
#     non-null long "is_remote"
#     non-null double "salary_min"
#     non-null double "salary_max"
#     non-null LocalDate "date"
#     non-null long "week"
#     non-null long "month"
#     non-null long "quarter"
#     non-null long "year"
#     non-null String "week_label"
#     non-null String "city"
#     non-null String "province_state"
#     non-null String "country"
#     non-null String "global_region"
#     non-null String "company_name"
#     non-null String "industry_sector"
#     non-null String "company_size_category"
#     non-null String "normalized_job_title"
#     non-null String "job_level"
#     non-null String "job_category"
#     non-null String "platform_name"
#   }
#   "skill_facts" {
#     non-null long PK "job_id"
#     non-null long "skill_id"
#     non-null double "extraction_confidence"
#     non-null String PK "skill_name"
#     non-null String "skill_type"
#     non-null String "skill_domain"
#     nullable long "time_id"
#     nullable long "location_id"
#     nullable long "company_id"
#     nullable long "position_id"
#     nullable long "platform_id"
#     nullable long "posting_count"
#     nullable long "job_age_days"
#     nullable long "has_salary"
#     nullable long "is_remote"
#     nullable double "salary_min"
#     nullable double "salary_max"
#     non-null LocalDate "date"
#     nullable long "week"
#     non-null long "month"
#     non-null long "quarter"
#     non-null long "year"
#     non-null String "week_label"
#     non-null String "city"
#     non-null String "province_state"
#     non-null String "country"
#     non-null String "global_region"
#     non-null String "company_name"
#     non-null String "industry_sector"
#     non-null String "company_size_category"
#     non-null String "normalized_job_title"
#     non-null String "job_level"
#     non-null String "job_category"
#     non-null String "platform_name"
#     non-null double "salary_midpoint"
#     non-null long "skill_count"
#   }
#   "skill_forecasts" {
#     non-null long "skill_id"
#     non-null String PK "forecast_week_label"
#     non-null long "forecast_year"
#     non-null long "forecast_week"
#     non-null String PK "skill_name"
#     non-null String PK "job_category"
#     non-null String PK "global_region"
#     non-null double "predicted_count"
#     non-null double "lower_bound"
#     non-null double "upper_bound"
#     non-null String "model_name"
#   }
#   "dim_time" {
#     non-null long PK "time_id"
#     non-null LocalDate "date"
#     nullable long "week"
#     nullable long "month"
#     nullable long "quarter"
#     nullable long "year"
#     non-null String "week_label"
#   }
#   "dim_location" {
#     non-null long PK "location_id"
#     non-null String "city"
#     non-null String "province_state"
#     non-null String "country"
#     non-null String "global_region"
#   }
#   "dim_company" {
#     non-null long PK "company_id"
#     non-null String "company_name"
#     non-null String "industry_sector"
#     non-null String "company_size_category"
#   }
#   "dim_position" {
#     non-null long PK "position_id"
#     non-null String "normalized_job_title"
#     non-null String "job_level"
#     non-null String "job_category"
#   }
#   "dim_platform" {
#     non-null long PK "platform_id"
#     non-null String "platform_name"
#     non-null String "regional_focus"
#   }
#   "dim_skill" {
#     non-null long PK "skill_id"
#     non-null String "skill_name"
#     non-null String "skill_type"
#     non-null String "skill_domain"
#   }
#   "job_postings" }o--o| "dim_company" : "company_id == company_id"
#   "job_postings" }o--o| "dim_location" : "location_id == location_id"
#   "job_postings" }o--o| "dim_platform" : "platform_id == platform_id"
#   "job_postings" }o--o| "dim_position" : "position_id == position_id"
#   "job_postings" }o--o| "dim_time" : "time_id == time_id"
#   "skill_facts" }o--o| "dim_skill" : "skill_id == skill_id"

# %% [markdown]
# ## 6. Widgets — Insight 1: Top 20 Skill Paling Banyak Diminta

# %%
top_skills = skill_cube.query(
    skill_cube.measures["Skill Postings"],
    levels=[skill_cube.hierarchies["Skill"]["skill_name"]],
    include_totals=False,
).sort_values("Skill Postings", ascending=False).head(20)

print("Top 20 Skills by Posting Count:")
top_skills
# Out:
# Top 20 Skills by Posting Count:
#                                                                      Skill Postings
# skill_domain              skill_type skill_name
# urchade/gliner_small-v2.1 Knowledge  bachelor s degree                            3
#                           Skill      attention to detail                          3
#                           Knowledge  ai                                           2
#                                      critical thinking                            2
#                                      tools                                        2
#                           Skill      analytical skills                            2
#                           Knowledge  microsoft office                             2
#                                      illustrator                                  2
#                           Skill      strong communication skills                  2
#                                      python                                       2
#                                      customer service skills                      2
#                           Knowledge  photoshop                                    2
#                                      generative ai                                2
#                                      high-impact evaluation systems               2
#                                      conoscenze specialistiche                    2
#                                      ai tools                                     1
#                                      adobe creative suite                         1
#                                      3d modeling software                         1
#                                      adobe creative cloud                         1
#                                      bachelors degree                             1

# %% [markdown]
# ## 7. Widgets — Insight 2: Tren Skill per Minggu

# %%
skill_trend = skill_cube.query(
    skill_cube.measures["Skill Postings"],
    levels=[
        skill_cube.hierarchies["Time"]["week_label"],
        skill_cube.hierarchies["Skill"]["skill_name"],
    ],
    include_totals=False,
)
print(f"Skill trend shape: {skill_trend.shape}")
skill_trend.head(10)
# Out:
# Skill trend shape: (175, 1)
#                                                                                                                        Skill Postings
# year quarter month week_label skill_domain              skill_type skill_name
# 2024 2       4     2024-W14   urchade/gliner_small-v2.1 Knowledge  convertkit pr                                                    1
#                                                                    extension ladders                                                1
#                                                                    knowledge of both state and federal procedural ...               1
#                                                                    p.e. license                                                     1
#                                                                    professional training certification                              1
#                                                                    strong attention to detail                                       1
#                                                                    superior organizational skills                                   1
#                    2024-W15   urchade/gliner_small-v2.1 Knowledge  3d modeling software                                             1
#                                                                    adobe creative suite                                             1
#                                                                    adobe creative suiteproficiency                                  1

# %% [markdown]
# ## 8. Widgets — Insight 3: Perbandingan Platform

# %%
# Dari Atoti cube
platform_atoti = job_cube.query(
    job_cube.measures["Total Postings"],
    job_cube.measures["Remote Rate"],
    job_cube.measures["Salary Coverage Rate"],
    levels=[
        job_cube.hierarchies["Platform"]["platform_name"],
        job_cube.hierarchies["Job"]["job_category"],
    ],
    include_totals=False,
)
print(f"Platform comparison (Atoti): {platform_atoti.shape}")
print(platform_atoti.head(10))

# Dari Materialized View mv_platform_monthly
platform_mv = pd.read_sql("""
    SELECT
        platform_name, job_category, global_region,
        SUM(posting_count)     AS total_postings,
        AVG(with_salary_count * 1.0 / NULLIF(posting_count, 0)) AS pct_with_salary,
        AVG(remote_count      * 1.0 / NULLIF(posting_count, 0)) AS pct_remote
    FROM mv_platform_monthly
    GROUP BY platform_name, job_category, global_region
    ORDER BY total_postings DESC;
""", engine)
print(f"\nPlatform MV: {len(platform_mv):,} rows")
platform_mv.head(10)
# Out:
# Platform comparison (Atoti): (5, 3)
#                             Total Postings  Remote Rate  Salary Coverage Rate
# platform_name job_category
# LinkedIn      Data                       3          0.0                   0.0
#               Design                    12          0.0              0.083333
#               Engineering                3     0.333333                   0.0
#               Management                53     0.113208              0.264151
#               Other                    264      0.05303              0.140152
#
# Platform MV: 10 rows
#   platform_name job_category  global_region  total_postings  pct_with_salary  \
# 0      LinkedIn        Other          Other           243.0         0.064078
# 1      LinkedIn   Management          Other            48.0         0.260870
# 2      LinkedIn        Other  North America            13.0         0.307692
# 3      LinkedIn       Design          Other            12.0         0.125000
# 4      LinkedIn        Other         Europe             8.0         0.000000
# 5      LinkedIn   Management  North America             4.0         0.500000
# 6      LinkedIn         Data          Other             3.0         0.000000
# 7      LinkedIn  Engineering          Other             2.0         0.000000
# 8      LinkedIn  Engineering  North America             1.0         0.000000
# 9      LinkedIn   Management         Europe             1.0         0.000000
#
#    pct_remote
# 0    0.001942
# 1    0.043478
# 2    1.000000
# 3    0.000000
# 4    0.000000
# 5    1.000000
# 6    0.000000
# 7    0.000000
# 8    1.000000
# 9    0.000000

# %% [markdown]
# ## 9. Widgets — Insight 4: Forecasting Skill 8 Minggu ke Depan

# %%
forecast_result = forecast_cube.query(
    forecast_cube.measures["Predicted Postings"],
    forecast_cube.measures["Forecast Lower"],
    forecast_cube.measures["Forecast Upper"],
    levels=[
        forecast_cube.hierarchies["Forecast Time"]["forecast_week_label"],
        forecast_cube.hierarchies["Skill"]["skill_name"],
    ],
    include_totals=False,
).sort_values("Predicted Postings", ascending=False)

print(f"Forecast result shape: {forecast_result.shape}")
forecast_result.head(15)
# Out:
# Forecast result shape: (1322, 3)
#                                                                    Predicted Postings  \
# forecast_year forecast_week forecast_week_label skill_name
# 2024          19            2024-W19            illustrator                       2.0
#               20            2024-W20            illustrator                       2.0
#               21            2024-W21            illustrator                       2.0
#               18            2024-W18            bachelor s degree                 2.0
#               17            2024-W17            illustrator                       2.0
#               23            2024-W23            analytical skills                 2.0
#               19            2024-W19            bachelor s degree                 2.0
#               20            2024-W20            analytical skills                 2.0
#               17            2024-W17            photoshop                         2.0
#               23            2024-W23            bachelor s degree                 2.0
#               22            2024-W22            photoshop                         2.0
#               20            2024-W20            photoshop                         2.0
#               21            2024-W21            bachelor s degree                 2.0
#               22            2024-W22            analytical skills                 2.0
#               18            2024-W18            illustrator                       2.0
#
#                                                                    Forecast Lower  \
# forecast_year forecast_week forecast_week_label skill_name
# 2024          19            2024-W19            illustrator                   2.0
#               20            2024-W20            illustrator                   2.0
#               21            2024-W21            illustrator                   2.0
#               18            2024-W18            bachelor s degree             2.0
#               17            2024-W17            illustrator                   2.0
#               23            2024-W23            analytical skills             2.0
#               19            2024-W19            bachelor s degree             2.0
#               20            2024-W20            analytical skills             2.0
#               17            2024-W17            photoshop                     2.0
#               23            2024-W23            bachelor s degree             2.0
#               22            2024-W22            photoshop                     2.0
#               20            2024-W20            photoshop                     2.0
#               21            2024-W21            bachelor s degree             2.0
#               22            2024-W22            analytical skills             2.0
#               18            2024-W18            illustrator                   2.0
#
#                                                                    Forecast Upper
# forecast_year forecast_week forecast_week_label skill_name
# 2024          19            2024-W19            illustrator                   2.0
#               20            2024-W20            illustrator                   2.0
#               21            2024-W21            illustrator                   2.0
#               18            2024-W18            bachelor s degree             2.0
#               17            2024-W17            illustrator                   2.0
#               23            2024-W23            analytical skills             2.0
#               19            2024-W19            bachelor s degree             2.0
#               20            2024-W20            analytical skills             2.0
#               17            2024-W17            photoshop                     2.0
#               23            2024-W23            bachelor s degree             2.0
#               22            2024-W22            photoshop                     2.0
#               20            2024-W20            photoshop                     2.0
#               21            2024-W21            bachelor s degree             2.0
#               22            2024-W22            analytical skills             2.0
#               18            2024-W18            illustrator                   2.0

# %% [markdown]
# ## 10. Widgets — Insight 5: Salary per Skill dan Job Level

# %%
salary_by_skill = skill_cube.query(
    skill_cube.measures["Avg Salary Midpoint"],
    skill_cube.measures["Skill Postings"],
    levels=[
        skill_cube.hierarchies["Skill"]["skill_name"],
        skill_cube.hierarchies["Job"]["job_level"],
    ],
    include_totals=False,
).sort_values("Avg Salary Midpoint", ascending=False)

print(f"Salary by skill/level: {salary_by_skill.shape}")
salary_by_skill.head(15)
# Out:
# Salary by skill/level: (173, 2)
#                                                                                                             Avg Salary Midpoint  \
# skill_domain              skill_type skill_name                                     job_category job_level
# urchade/gliner_small-v2.1 Knowledge  iq/oq/pq qualifications                        Other        Unknown               135200.0
#                                      lims                                           Other        Unknown               135200.0
#                                      professional training certification            Other        Unknown               105000.0
#                                      florida 2-15 health, life annuities license    Other        Senior                 90000.0
#                                      licensure                                      Other        Unknown                83200.0
#                                      lynx system                                    Other        Manager                80000.0
#                                      tracker                                        Other        Unknown                75000.0
#                                      excellent communication skills                 Other        Unknown                75000.0
#                                      trackertracker                                 Other        Unknown                75000.0
#                                      mechanical license                             Other        Unknown                70000.0
#                                      extension ladders                              Other        Unknown                67600.0
#                           Skill      multi-tasking                                  Other        Manager                65000.0
#                           Knowledge  bachelor s degree in science or engineering    Other        Unknown                62500.0
#                           Skill      excellent computer skills                      Other        Unknown                62500.0
#                                      strong verbal and written communication skills Other        Unknown                62500.0
#
#                                                                                                             Skill Postings
# skill_domain              skill_type skill_name                                     job_category job_level
# urchade/gliner_small-v2.1 Knowledge  iq/oq/pq qualifications                        Other        Unknown                 1
#                                      lims                                           Other        Unknown                 1
#                                      professional training certification            Other        Unknown                 1
#                                      florida 2-15 health, life annuities license    Other        Senior                  1
#                                      licensure                                      Other        Unknown                 1
#                                      lynx system                                    Other        Manager                 1
#                                      tracker                                        Other        Unknown                 1
#                                      excellent communication skills                 Other        Unknown                 1
#                                      trackertracker                                 Other        Unknown                 1
#                                      mechanical license                             Other        Unknown                 1
#                                      extension ladders                              Other        Unknown                 1
#                           Skill      multi-tasking                                  Other        Manager                 1
#                           Knowledge  bachelor s degree in science or engineering    Other        Unknown                 1
#                           Skill      excellent computer skills                      Other        Unknown                 1
#                                      strong verbal and written communication skills Other        Unknown                 1

# %% [markdown]
# ## 11. Widgets — Insight 6: Distribusi Geografis Posting

# %%
geo_distribution = job_cube.query(
    job_cube.measures["Total Postings"],
    job_cube.measures["Remote Rate"],
    levels=[
        job_cube.hierarchies["Location"]["global_region"],
        job_cube.hierarchies["Location"]["country"],
        job_cube.hierarchies["Job"]["job_category"],
    ],
    include_totals=True,
)
print(f"Geo distribution: {geo_distribution.shape}")
geo_distribution.head(15)
# Out:
# Geo distribution: (134, 2)
#                                            Total Postings  Remote Rate
# global_region country        job_category
# <NA>          <NA>           <NA>                     335     0.062687
# Europe        <NA>           <NA>                       9          0.0
#               Germany        <NA>                       1          0.0
#                              Other                      1          0.0
#               Netherlands    <NA>                       2          0.0
#                              Other                      2          0.0
#               Norway         <NA>                       1          0.0
#                              Other                      1          0.0
#               Switzerland    <NA>                       1          0.0
#                              Management                 1          0.0
#               United Kingdom <NA>                       4          0.0
#                              Other                      4          0.0
# North America <NA>           <NA>                      18          1.0
#               United States  <NA>                      18          1.0
#                              Engineering                1          1.0

# %% [markdown]
# ## 12. Widgets — Insight 7: Top Skill per Job Category (dari MV)

# %%
top_skills_per_cat = pd.read_sql("""
    SELECT
        job_category, skill_name, skill_domain,
        SUM(posting_count) AS total_postings
    FROM mv_weekly_skill_demand
    GROUP BY job_category, skill_name, skill_domain
    ORDER BY job_category, total_postings DESC
    LIMIT 200;
""", engine)

top5_per_cat = (
    top_skills_per_cat
    .groupby("job_category")
    .head(5)
    .reset_index(drop=True)
)
print(f"Top 5 skill per category: {len(top5_per_cat):,} rows")
top5_per_cat
# Out:
# Top 5 skill per category: 25 rows
#    job_category                      skill_name               skill_domain  \
# 0          Data                             sql  urchade/gliner_small-v2.1
# 1          Data                    data analyst  urchade/gliner_small-v2.1
# 2          Data                              ai  urchade/gliner_small-v2.1
# 3          Data                            data  urchade/gliner_small-v2.1
# 4          Data                       reporting  urchade/gliner_small-v2.1
# 5        Design                   generative ai  urchade/gliner_small-v2.1
# 6        Design               critical thinking  urchade/gliner_small-v2.1
# 7        Design            adobe creative suite  urchade/gliner_small-v2.1
# 8        Design        creative problem-solving  urchade/gliner_small-v2.1
# 9        Design                  tendem project  urchade/gliner_small-v2.1
# 10  Engineering               analytical skills  urchade/gliner_small-v2.1
# 11  Engineering                            html  urchade/gliner_small-v2.1
# 12  Engineering                            math  urchade/gliner_small-v2.1
# 13  Engineering                       javascrip  urchade/gliner_small-v2.1
# 14  Engineering                        software  urchade/gliner_small-v2.1
# 15   Management  high-impact evaluation systems  urchade/gliner_small-v2.1
# 16   Management                             pmo  urchade/gliner_small-v2.1
# 17   Management           leadership experience  urchade/gliner_small-v2.1
# 18   Management               commercial acumen  urchade/gliner_small-v2.1
# 19   Management    associates or college degree  urchade/gliner_small-v2.1
# 20        Other             attention to detail  urchade/gliner_small-v2.1
# 21        Other         customer service skills  urchade/gliner_small-v2.1
# 22        Other                           tools  urchade/gliner_small-v2.1
# 23        Other               bachelor s degree  urchade/gliner_small-v2.1
# 24        Other     strong communication skills  urchade/gliner_small-v2.1
#
#     total_postings
# 0              1.0
# 1              1.0
# 2              1.0
# 3              1.0
# 4              1.0
# 5              2.0
# 6              2.0
# 7              1.0
# 8              1.0
# 9              1.0
# 10             1.0
# 11             1.0
# 12             1.0
# 13             1.0
# 14             1.0
# 15             2.0
# 16             1.0
# 17             1.0
# 18             1.0
# 19             1.0
# 20             3.0
# 21             2.0
# 22             2.0
# 23             2.0
# 24             2.0

# %% [markdown]
# ## 12. OLAP CUBE Query (PostgreSQL)

# %%
cube_query = pd.read_sql("""
    SELECT
        dt.year, dt.quarter,
        ds.skill_name, ds.skill_domain,
        dp.job_category, dl.global_region,
        COUNT(DISTINCT f.job_id) AS posting_count,
        AVG(f.salary_max)        AS avg_salary_max
    FROM fact_job_posting f
    JOIN bridge_job_skill b ON f.job_id      = b.job_id
    JOIN dim_skill ds        ON b.skill_id   = ds.skill_id
    JOIN dim_time dt         ON f.time_id    = dt.time_id
    JOIN dim_position dp     ON f.position_id = dp.position_id
    JOIN dim_location dl     ON f.location_id = dl.location_id
    GROUP BY CUBE(
        dt.year, dt.quarter,
        ds.skill_name, ds.skill_domain,
        dp.job_category, dl.global_region
    )
    HAVING COUNT(DISTINCT f.job_id) > 0
    ORDER BY dt.year NULLS LAST, posting_count DESC
    LIMIT 1000;
""", engine)

print(f"CUBE query: {len(cube_query):,} rows")
cube_query.head(10)
# Out:
# CUBE query: 1,000 rows
#    year  quarter skill_name               skill_domain job_category  \
# 0  2024      NaN       None                       None         None
# 1  2024      2.0       None                       None         None
# 2  2024      NaN       None  urchade/gliner_small-v2.1         None
# 3  2024      2.0       None  urchade/gliner_small-v2.1         None
# 4  2024      2.0       None  urchade/gliner_small-v2.1         None
# 5  2024      2.0       None                       None         None
# 6  2024      NaN       None  urchade/gliner_small-v2.1         None
# 7  2024      NaN       None                       None         None
# 8  2024      2.0       None  urchade/gliner_small-v2.1        Other
# 9  2024      NaN       None                       None        Other
#
#   global_region  posting_count  avg_salary_max
# 0          None             48    81082.962963
# 1          None             48    81082.962963
# 2          None             48    81082.962963
# 3          None             48    81082.962963
# 4         Other             43    81169.600000
# 5         Other             43    81169.600000
# 6         Other             43    81169.600000
# 7         Other             43    81169.600000
# 8          None             42    81082.962963
# 9          None             42    81082.962963

# %% [markdown]
# ## 13. Performance Benchmark
# Perbandingan query dengan dan tanpa Materialized View.

# %%
import time

query_raw = """
    SELECT ds.skill_name, dt.week_label, COUNT(DISTINCT f.job_id) AS cnt
    FROM fact_job_posting f
    JOIN bridge_job_skill b ON f.job_id      = b.job_id
    JOIN dim_skill ds        ON b.skill_id   = ds.skill_id
    JOIN dim_time dt         ON f.time_id    = dt.time_id
    JOIN dim_position dp     ON f.position_id = dp.position_id
    JOIN dim_location dl     ON f.location_id = dl.location_id
    GROUP BY ds.skill_name, dt.week_label
    ORDER BY cnt DESC LIMIT 20;
"""

query_mv = """
    SELECT skill_name, week_label, SUM(posting_count) AS cnt
    FROM mv_weekly_skill_demand
    GROUP BY skill_name, week_label
    ORDER BY cnt DESC LIMIT 20;
"""

runs = 3
times_raw, times_mv = [], []
for _ in range(runs):
    t0 = time.time(); pd.read_sql(query_raw, engine); times_raw.append(time.time() - t0)
    t0 = time.time(); pd.read_sql(query_mv,  engine); times_mv.append(time.time()  - t0)

avg_raw = sum(times_raw) / runs
avg_mv  = sum(times_mv)  / runs
speedup = avg_raw / avg_mv if avg_mv > 0 else float("inf")

print(f"Tanpa  Materialized View : {avg_raw:.4f}s")
print(f"Dengan Materialized View : {avg_mv:.4f}s")
print(f"Speedup                  : {speedup:.2f}x")
# Out:
# Tanpa  Materialized View : 0.7283s
# Dengan Materialized View : 0.5537s
# Speedup                  : 1.32x

# %% [markdown]
# ## 14. Buka Atoti Dashboard

# %%
print("TalentTrack Atoti DataMart READY")
print(f"  Dashboard : {session.url}")
print("  Cubes     : JobPostings | SkillDemand | SkillForecast")
# Out:
# TalentTrack Atoti DataMart READY
#   Dashboard : http://localhost:9090
#   Cubes     : JobPostings | SkillDemand | SkillForecast
